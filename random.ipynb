# %%
# %run imports.py

# %%
a = 1e-2*np.random.randn(10000)
plt.hist(a, bins=100); plt.xlim(-4e-2, 4e-2)
plt.show()

a = .4*np.random.randn(10000)
a = 3e-2*np.tanh(a)

plt.hist(a, bins=100); plt.xlim(-4e-2, 4e-2)
plt.show()
