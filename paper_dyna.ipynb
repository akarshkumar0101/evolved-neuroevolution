# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run imports.py

# %%
x = torch.randn(2)


xs = []
t = torch.linspace(0, 20, 100)
sint = -t.cos()+1

for i in range(len(t)):
    ti = t[i]
    sinti = sint[i]
    
    xs.append(x)
    x = x+sinti*torch.randn(2)*0.01
xs = torch.stack(xs)

# %%
plt.plot(t, sint)

# %%
plt.scatter(*xs.T.numpy(), c=sint.numpy())
plt.plot(*xs.T.numpy())
